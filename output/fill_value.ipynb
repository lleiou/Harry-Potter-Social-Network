# %%
import pandas as pd
matrix = pd.read_csv("book6_relation.csv", index_col=0)
matrix
# Out:
#                         Harry Potter  Ronald Weasley  Albus Dumbledore  \
# Harry Potter                       1               1                 1
# Ronald Weasley                     1               1                 1
# Albus Dumbledore                   1               1                 1
# Hermione Granger                   1               1                 1
# Ginevra Weasley                    1               1                 1
# Draco Malfoy                       1               1                 1
# Lord Voldemort                     1               1                 1
# Horace Slughorn                    1               1                 1
# Narcissa Malfoy                    1               1                 1
# Severus Snape                      1               1                 1
# Lucius Malfoy                      1               1                 1
# Molly Weasley                      1               1                 1
# ...

# %%
for i in range(30):
    for j in range(i,30):
        matrix.iloc[j,i] = matrix.iloc[i,j]

# %%
for i in range(30):
    for j in range(30):
        if matrix.iloc[j,i] != matrix.iloc[i,j]
# Out:
#                         Harry Potter  Ronald Weasley  Albus Dumbledore  \
# Harry Potter                       1               1                 1
# Ronald Weasley                     1               1                 1
# Albus Dumbledore                   1               1                 1
# Hermione Granger                   1               1                 1
# Ginevra Weasley                    1               1                 1
# Draco Malfoy                      -1              -1                 1
# Lord Voldemort                    -1              -1                -1
# Horace Slughorn                    1               0                 1
# Narcissa Malfoy                   -1              -1                -1
# Severus Snape                     -1              -1                 1
# Lucius Malfoy                     -1              -1                -1
# Molly Weasley                      1               1                 1
# ...
