# %%
import numpy as np
import itertools
import pandas as pd
import re

# %%
nick = {}
with open('name_list.txt', 'rb') as f:
    for line in f:
        if line.strip().partition("\t")[-1] != '':
            nick[line.strip().partition("\t")[0]] = line.strip().partition("\t")[0].split(' ')+line.strip().partition("\t")[-1][1:-1].split(', ')
        else:
            nick[line.strip().partition("\t")[0]] = line.strip().partition("\t")[0].split(' ')
f.close()

# %%
names_v1 = []
for x in nick.keys():
    with open('sentences2.txt', 'rb') as f:
        for line in f:
            if x.split(' ')[0].lower() in re.findall(r"[\w']+", line.lower()):
                names_v1.append(x)
            if nick[x][2:] != []:
                for name in nick[x][2:]:
                    if set(name.lower().split(' ')).intersection(re.findall(r"[\w']+", line.lower())) ==  set(name.lower().split(' ')):
                        names_v1.append(x)

# %%
allnames = sorted(list(set(names_v1)))

# %%
for x in allnames:
    if len(x.split(' ')) == 1:
        allnames.remove(x)
    if (len(x.split(' ')) == 3 and x.split(' ')[-1].lower() == 'potter'):
        allnames.remove(x)

# %%
# need to run it again
for x in allnames:
    if len(x.split(' ')) == 1:
        allnames.remove(x)
    if (len(x.split(' ')) == 3 and x.split(' ')[-1].lower() == 'potter'):
        allnames.remove(x)

# %%
names_set = []
for a,b in itertools.combinations(allnames,2):
    names_set.append([a,b])

# %%
ep = {}
for x in allnames:
    ep[x] = nick[x]
    
import pickle
with open("nick_ep2", "wb") as f:
    pickle.dump(ep, f)

# %%
ep
# Out:
# {'"Nearly Headless" Nick': ['"Nearly', 'Headless"', 'Nick'],
#  'Albus Dumbledore': ['Albus', 'Dumbledore', 'Percival', 'Wulfric', 'Brian'],
#  'Alicia Spinnet': ['Alicia', 'Spinnet'],
#  'Angelina Johnson': ['Angelina', 'Johnson'],
#  'Argus Filch': ['Argus', 'Filch'],
#  'Arthur Weasley': ['Arthur', 'Weasley'],
#  'Charlie Weasley': ['Charlie', 'Weasley'],
#  'Colin Creevey': ['Colin', 'Creevey'],
#  'Cornelius Fudge': ['Cornelius', 'Fudge', 'Oswald'],
#  'Dean Thomas': ['Dean', 'Thomas'],
#  'Draco Malfoy': ['Draco', 'Malfoy'],
#  'Dudley Dursley': ['Dudley', 'Dursley'],
#  'Ernie Macmillan': ['Ernie', 'Macmillan'],
#  'Fluffy': ['Fluffy'],
#  'Frank Bryce': ['Frank', 'Bryce'],
#  'Frank Longbottom': ['Frank', 'Longbottom'],
#  'Fred Weasley': ['Fred', 'Weasley'],
#  'George Weasley': ['George', 'Weasley'],
#  'Gilderoy Lockhart': ['Gilderoy', 'Lockhart'],
#  'Ginevra Weasley': ['Ginevra', 'Weasley', 'Ginny'],
#  'Godric Gryffindor': ['Godric', 'Gryffindor'],
#  'Hannah Abbott': ['Hannah', 'Abbott'],
#  'Harry Potter': ['Harry', 'Potter'],
#  'Helga Hufflepuff': ['Helga', 'Hufflepuff'],
#  'Hermione Granger': ['Hermione', 'Granger', 'Jean'],
#  'Justin Finch-Fletchley': ['Justin', 'Finch-Fletchley'],
#  'Katie Bell': ['Katie', 'Bell'],
#  'Lavender Brown': ['Lavender', 'Brown'],
#  'Lee Jordan': ['Lee', 'Jordan'],
#  'Lord Voldemort': ['Lord', 'Voldemort', 'Tom', 'Marvolo'],
#  'Lucius Malfoy': ['Lucius', 'Malfoy'],
#  'Madam Malkin': ['Madam', 'Malkin'],
#  'Madam Rosmerta': ['Madam', 'Rosmerta'],
#  'Mafalda Hopkirk': ['Mafalda', 'Hopkirk'],
#  'Marcus Flint': ['Marcus', 'Flint'],
#  'Marvolo Gaunt': ['Marvolo', 'Gaunt'],
#  'Mary Cattermole': ['Mary', 'Cattermole'],
#  'Mary Riddle': ['Mary', 'Riddle'],
#  'Millicent Bulstrode': ['Millicent', 'Bulstrode'],
#  'Minerva McGonagall': ['Minerva', 'McGonagall'],
#  'Molly Weasley': ['Molly', 'Weasley', 'Mrs Weasley'],
#  'Mundungus Fletcher': ['Mundungus', 'Fletcher'],
#  'Neville Longbottom': ['Neville', 'Longbottom'],
#  'Newt Scamander': ['Newt', 'Scamander'],
#  'Oliver Wood': ['Oliver', 'Wood'],
#  'Parvati Patil': ['Parvati', 'Patil'],
#  'Penelope Clearwater': ['Penelope', 'Clearwater'],
#  'Percy Weasley': ['Percy', 'Weasley', 'Ignatius'],
#  'Peter Pettigrew': ['Peter', 'Pettigrew', 'Scabbers', 'Wormtail'],
#  'Petunia Dursley': ['Petunia', 'Dursley'],
#  'Phineas Nigellus Black': ['Phineas', 'Nigellus', 'Black'],
#  'Regulus Arcturus Black': ['Regulus', 'Arcturus', 'Black'],
#  'Ronald Weasley': ['Ronald', 'Weasley', 'Ron'],
#  'Rowena Ravenclaw': ['Rowena', 'Ravenclaw'],
#  'Rubeus Hagrid': ['Rubeus', 'Hagrid'],
#  'Salazar Slytherin': ['Salazar', 'Slytherin'],
#  'Seamus Finnigan': ['Seamus', 'Finnigan'],
#  'Severus Snape': ['Severus', 'Snape'],
#  'Teddy Lupin': ['Teddy', 'Lupin'],
#  'Tom Riddle': ['Tom', 'Riddle'],
#  'Vernon Dursley': ['Vernon', 'Dursley'],
#  'William Weasley': ['William', 'Weasley', 'Bill']}

# %%
zero_data = np.zeros(shape=(len(allnames),len(allnames)))
family_matrix = pd.DataFrame(zero_data,index = [range(len(allnames))], columns = [range(len(allnames))])
family_matrix.index = allnames
family_matrix.columns = allnames

# %%
import time
start_time = time.time()
#allnames = allnames[0:333]
#cooccurrence = {}
for x,y in names_set:
    with open('sentences2.txt', 'rb') as f:
        for line in f:
            for name1, name2 in itertools.product(ep[x], ep[y]):
                if name1 in ['Mrs Weasley', 'The Grey'] or name2 in ['Mrs Weasley', 'The Grey']:
                    if set(name1.lower().split(' ')).intersection(re.findall(r"[\w']+", line.lower())) ==  set(name1.lower().split(' ')) and set(name2.lower().split(' ')).intersection(re.findall(r"[\w']+", line.lower())) ==  set(name2.lower().split(' ')):
                        family_matrix.loc[x,y] += 1
                        family_matrix.loc[y,x] += 1
                else:
                    if name1.lower() in re.findall(r"[\w']+", line.lower()) and name2.lower() in re.findall(r"[\w']+", line.lower()):
                        family_matrix.loc[x,y] += 1
                        family_matrix.loc[y,x] += 1

# %%
print time.time()-start_time
# Out:
# 781.942444086

# %%
family_matrix
# Out:
#                         "Nearly Headless" Nick  Albus Dumbledore  \
# "Nearly Headless" Nick                     0.0               0.0
# Albus Dumbledore                           0.0               0.0
# Alicia Spinnet                             0.0               0.0
# Angelina Johnson                           0.0               0.0
# Argus Filch                                2.0               2.0
# Arthur Weasley                             0.0               4.0
# Charlie Weasley                            0.0               4.0
# Colin Creevey                              0.0               2.0
# Cornelius Fudge                            0.0               8.0
# Dean Thomas                                0.0               0.0
# Draco Malfoy                               0.0               5.0
# Dudley Dursley                             0.0               0.0
# Ernie Macmillan                            2.0               0.0
# Fluffy                                     0.0               0.0
# Frank Bryce                                0.0               0.0
# Frank Longbottom                           0.0               0.0
# Fred Weasley                               0.0               4.0
# George Weasley                             0.0               4.0
# Gilderoy Lockhart                          0.0               5.0
# Ginevra Weasley                            0.0               5.0
# Godric Gryffindor                          1.0               3.0
# Hannah Abbott                              0.0               0.0
# Harry Potter                               8.0              41.0
# Helga Hufflepuff                           0.0               1.0
# Hermione Granger                           1.0               2.0
# Justin Finch-Fletchley                     8.0               1.0
# Katie Bell                                 0.0               0.0
# Lavender Brown                             0.0               0.0
# Lee Jordan                                 0.0               0.0
# Lord Voldemort                             0.0               7.0
# ...                                        ...               ...
# Madam Rosmerta                             1.0               2.0
# Mafalda Hopkirk                            0.0               0.0
# Marcus Flint                               0.0               0.0
# Marvolo Gaunt                              0.0               0.0
# Mary Cattermole                            0.0               1.0
# Mary Riddle                                0.0               5.0
# Millicent Bulstrode                        0.0               0.0
# Minerva McGonagall                         1.0              10.0
# Molly Weasley                              0.0               5.0
# Mundungus Fletcher                         0.0               0.0
# Neville Longbottom                         0.0               0.0
# Newt Scamander                             0.0               0.0
# Oliver Wood                                0.0               0.0
# Parvati Patil                              0.0               0.0
# Penelope Clearwater                        0.0               0.0
# Percy Weasley                              0.0               4.0
# Peter Pettigrew                            0.0               0.0
# Petunia Dursley                            0.0               0.0
# Phineas Nigellus Black                     4.0               1.0
# Regulus Arcturus Black                     4.0               1.0
# Ronald Weasley                             0.0              13.0
# Rowena Ravenclaw                           1.0               0.0
# Rubeus Hagrid                              0.0              14.0
# Salazar Slytherin                          0.0               5.0
# Seamus Finnigan                            0.0               0.0
# Severus Snape                              0.0               2.0
# Teddy Lupin                                0.0               0.0
# Tom Riddle                                 0.0               5.0
# Vernon Dursley                             0.0               0.0
# William Weasley                            0.0               4.0
#
#                         Alicia Spinnet  Angelina Johnson  Argus Filch  \
# "Nearly Headless" Nick             0.0               0.0          2.0
# Albus Dumbledore                   0.0               0.0          2.0
# Alicia Spinnet                     0.0               1.0          0.0
# Angelina Johnson                   1.0               0.0          0.0
# Argus Filch                        0.0               0.0          0.0
# Arthur Weasley                     4.0               0.0          0.0
# Charlie Weasley                    4.0               0.0          0.0
# Colin Creevey                      0.0               0.0          0.0
# Cornelius Fudge                    0.0               0.0          0.0
# Dean Thomas                        0.0               0.0          0.0
# Draco Malfoy                       0.0               0.0          2.0
# Dudley Dursley                     0.0               0.0          0.0
# Helga Hufflepuff                    0.0          0.0       ...
# Hermione Granger                    0.0          0.0       ...
# Justin Finch-Fletchley              0.0          0.0       ...
# Katie Bell                          0.0          0.0       ...
# Lavender Brown                      0.0          4.0       ...
# Lee Jordan                          0.0          0.0       ...
# Lord Voldemort                      0.0          0.0       ...
# ...                                 ...          ...       ...
# Madam Rosmerta                      0.0          0.0       ...
# Mafalda Hopkirk                     0.0          0.0       ...
# Marcus Flint                        0.0          0.0       ...
# Marvolo Gaunt                       0.0          0.0       ...
# Mary Cattermole                     0.0          0.0       ...
# Mary Riddle                         0.0          0.0       ...
# Millicent Bulstrode                 0.0          0.0       ...
# Minerva McGonagall                  0.0          0.0       ...
# Molly Weasley                       0.0          0.0       ...
# Mundungus Fletcher                  0.0          0.0       ...
# Neville Longbottom                  0.0         11.0       ...
# Newt Scamander                      0.0          0.0       ...
# Oliver Wood                         0.0          0.0       ...
# Parvati Patil                       0.0          0.0       ...
# Penelope Clearwater                 0.0          0.0       ...
# Percy Weasley                       0.0          0.0       ...
# Peter Pettigrew                     0.0          0.0       ...
# Petunia Dursley                     0.0          0.0       ...
# Phineas Nigellus Black              0.0          0.0       ...
# Regulus Arcturus Black              0.0          0.0       ...
# Ronald Weasley                      0.0          7.0       ...
# Rowena Ravenclaw                    0.0          0.0       ...
# Rubeus Hagrid                       6.0          0.0       ...
# Salazar Slytherin                   0.0          2.0       ...
# Seamus Finnigan                     0.0         12.0       ...
# Severus Snape                       0.0          1.0       ...
# Teddy Lupin                         0.0          0.0       ...
# Tom Riddle                          0.0          0.0       ...
# Vernon Dursley                      0.0          0.0       ...
# William Weasley                     0.0          0.0       ...
#
#                         Ronald Weasley  Rowena Ravenclaw  Rubeus Hagrid  \
# "Nearly Headless" Nick             0.0               1.0            0.0
# Albus Dumbledore                  13.0               0.0           14.0
# Alicia Spinnet                     4.0               0.0            0.0
# Angelina Johnson                   0.0               0.0            0.0
# Argus Filch                        6.0               0.0            0.0
# Arthur Weasley                   200.0               1.0            4.0
# Charlie Weasley                  186.0               1.0            3.0
# Colin Creevey                      3.0               0.0            0.0
# Cornelius Fudge                    0.0               0.0            6.0
# Dean Thomas                        7.0               0.0            0.0
# Draco Malfoy                      35.0               0.0            5.0
# Dudley Dursley                     1.0               0.0            0.0
# Ernie Macmillan                    2.0               0.0            0.0
# Fluffy                             0.0               0.0            1.0
# Frank Bryce                        0.0               0.0            0.0
# Frank Longbottom                   0.0               0.0            0.0
# Fred Weasley                     219.0               1.0            3.0
# George Weasley                   216.0               1.0            3.0
# Gilderoy Lockhart                 26.0               0.0            7.0
# Ginevra Weasley                  233.0               2.0            3.0
# Godric Gryffindor                 11.0               6.0            1.0
# Hannah Abbott                      1.0               0.0            0.0
# Harry Potter                     290.0               1.0           41.0
# Helga Hufflepuff                   4.0               6.0            1.0
# Hermione Granger                 133.0               1.0            8.0
# Justin Finch-Fletchley             4.0               0.0            1.0
# Katie Bell                         2.0               0.0            0.0
# Lavender Brown                     0.0               0.0            0.0
# Lee Jordan                         3.0               2.0            0.0
# Lord Voldemort                     0.0               0.0            2.0
# ...                                ...               ...            ...
# Madam Rosmerta                     4.0               0.0            0.0
# Mafalda Hopkirk                    0.0               0.0            0.0
# Marcus Flint                       1.0               0.0            0.0
# Marvolo Gaunt                      0.0               0.0            0.0
# Mary Cattermole                    1.0               0.0            0.0
# Mary Riddle                        5.0               0.0            6.0
# Millicent Bulstrode                4.0               0.0            0.0
# Minerva McGonagall                 6.0               0.0            2.0
# Molly Weasley                    253.0               1.0            4.0
# Mundungus Fletcher                 0.0               0.0            0.0
# Neville Longbottom                 6.0               0.0            0.0
# Newt Scamander                     0.0               0.0            0.0
# Oliver Wood                        1.0               0.0            0.0
# Parvati Patil                      0.0               0.0            0.0
# Penelope Clearwater                0.0               4.0            0.0
# Percy Weasley                    213.0               1.0            4.0
# Peter Pettigrew                    5.0               0.0            0.0
# Petunia Dursley                    0.0               0.0            0.0
# Phineas Nigellus Black             4.0               0.0            4.0
# Regulus Arcturus Black             4.0               0.0            4.0
# Ronald Weasley                     0.0               1.0           19.0
# Rowena Ravenclaw                   1.0               0.0            0.0
# Rubeus Hagrid                     19.0               0.0            0.0
# Salazar Slytherin                 10.0               8.0            1.0
# Seamus Finnigan                    4.0               0.0            0.0
# Severus Snape                      9.0               0.0            2.0
# Teddy Lupin                        0.0               0.0            0.0
# Tom Riddle                         4.0               0.0            8.0
# Vernon Dursley                     0.0               0.0            0.0
# William Weasley                  188.0               1.0            3.0
#
#                         Salazar Slytherin  Seamus Finnigan  Severus Snape  \
# "Nearly Headless" Nick                0.0              0.0            0.0
# Albus Dumbledore                      5.0              0.0            2.0
# Alicia Spinnet                        0.0              0.0            0.0
# Angelina Johnson                      0.0              0.0            0.0
# Argus Filch                           0.0              0.0            0.0
# Arthur Weasley                        1.0              1.0            0.0
# Charlie Weasley                       1.0              1.0            0.0
# Colin Creevey                         0.0              0.0            0.0
# Cornelius Fudge                       0.0              0.0            0.0
# Dean Thomas                           2.0             12.0            1.0
# Draco Malfoy                         10.0              0.0            7.0
# Dudley Dursley                        0.0              0.0            0.0
# Ernie Macmillan                       0.0              0.0            0.0
# Fluffy                                0.0              0.0            0.0
# Frank Bryce                           0.0              0.0            0.0
# Frank Longbottom                      0.0              2.0            0.0
# Fred Weasley                          2.0              1.0            0.0
# George Weasley                        2.0              1.0            0.0
# Gilderoy Lockhart                     0.0              2.0           12.0
# Ginevra Weasley                       1.0              1.0            0.0
# Godric Gryffindor                    10.0              2.0            1.0
# Hannah Abbott                         0.0              0.0            0.0
# Harry Potter                         27.0              0.0           28.0
# Helga Hufflepuff                      5.0              0.0            0.0
# Hermione Granger                      7.0              1.0            4.0
# Justin Finch-Fletchley                1.0              1.0            1.0
# Katie Bell                            0.0              0.0            1.0
# Lavender Brown                        0.0              0.0            1.0
# Lee Jordan                            2.0              0.0            0.0
# Lord Voldemort                        8.0              0.0            0.0
# ...                                   ...              ...            ...
# Madam Rosmerta                        0.0              0.0            0.0
# Mafalda Hopkirk                       0.0              0.0            0.0
# Marcus Flint                          2.0              0.0            0.0
# Marvolo Gaunt                         1.0              0.0            1.0
# Mundungus Fletcher              0.0         0.0             0.0
# Neville Longbottom              0.0         0.0             0.0
# Newt Scamander                  0.0         0.0             0.0
# Oliver Wood                     0.0         0.0             0.0
# Parvati Patil                   0.0         0.0             0.0
# Penelope Clearwater             0.0         0.0             0.0
# Percy Weasley                   0.0         4.0             0.0
# Peter Pettigrew                 0.0         0.0             0.0
# Petunia Dursley                 0.0         0.0             8.0
# Phineas Nigellus Black          0.0         1.0             1.0
# Regulus Arcturus Black          0.0         1.0             1.0
# Ronald Weasley                  0.0         4.0             0.0
# Rowena Ravenclaw                0.0         0.0             0.0
# Rubeus Hagrid                   0.0         8.0             0.0
# Salazar Slytherin               0.0         2.0             0.0
# Seamus Finnigan                 0.0         0.0             0.0
# Severus Snape                   0.0         1.0             0.0
# Teddy Lupin                     0.0         0.0             0.0
# Tom Riddle                      0.0         0.0             0.0
# Vernon Dursley                  0.0         0.0             0.0
# William Weasley                 0.0         1.0             0.0
#
#                         William Weasley
# "Nearly Headless" Nick              0.0
# Albus Dumbledore                    4.0
# Alicia Spinnet                      4.0
# Angelina Johnson                    0.0
# Argus Filch                         0.0
# Arthur Weasley                    185.0
# Charlie Weasley                   173.0
# Colin Creevey                       2.0
# Cornelius Fudge                     0.0
# Dean Thomas                         0.0
# Draco Malfoy                       14.0
# Dudley Dursley                      0.0
# Ernie Macmillan                     0.0
# Fluffy                              0.0
# Frank Bryce                         0.0
# Frank Longbottom                    0.0
# Fred Weasley                      188.0
# George Weasley                    186.0
# Gilderoy Lockhart                   2.0
# Ginevra Weasley                   198.0
# Godric Gryffindor                   2.0
# Hannah Abbott                       0.0
# Harry Potter                       38.0
# Helga Hufflepuff                    1.0
# Hermione Granger                    9.0
# Justin Finch-Fletchley              0.0
# Katie Bell                          0.0
# Lavender Brown                      0.0
# Lee Jordan                          3.0
# Lord Voldemort                      0.0
# ...                                 ...
# Madam Rosmerta                      0.0
# Mafalda Hopkirk                     0.0
# Marcus Flint                        0.0
# Marvolo Gaunt                       0.0
# Mary Cattermole                     0.0
# Mary Riddle                         1.0
# Millicent Bulstrode                 0.0
# Minerva McGonagall                  1.0
# Molly Weasley                     234.0
# Mundungus Fletcher                  0.0
# Neville Longbottom                  0.0
# Newt Scamander                      0.0
# Oliver Wood                         1.0
# Parvati Patil                       0.0
# Penelope Clearwater                 0.0
# Percy Weasley                     186.0
# Peter Pettigrew                     1.0
# Petunia Dursley                     0.0
# Phineas Nigellus Black              0.0
# Regulus Arcturus Black              0.0
# Ronald Weasley                    188.0
# Rowena Ravenclaw                    1.0
# Rubeus Hagrid                       3.0
# Salazar Slytherin                   1.0
# Seamus Finnigan                     1.0
# Severus Snape                       0.0
# Teddy Lupin                         0.0
# Tom Riddle                          1.0
# Vernon Dursley                      0.0
# William Weasley                     0.0
#
# [62 rows x 62 columns]

# %%
family_matrix.to_csv("book2_co_occurrence.csv")

# %%
######################################### all names code
with open('allnames.txt', 'rb') as f:
    for line in f:
        temp = line[1:-1].split(', ')
        
f.close()
allnames=[]
for item in temp:
    allnames.append(item[1:-1].strip())
